# %% [markdown]
# # G-SHAP classification demonstration
#
# We can use SHAP for classification explanations. Why did our model predict that observation $x$ belongs to class $c$?
#
# We can generalize this question using G-SHAP values. In this example, we ask two questions of the sklearn iris dataset. Suppose we have an iris $x$ which our model classifies as a Versicolour iris. We will ask:
#
# 1. Why is this observation classified as Versicolour, rather than Setosa?
# 2. Why is this observation classified as Versicolour, rather than Virginica?
#
# What we find is that petal length is usually the most important feature. Additionally, petal length is relatively less important, and petal width relatively more important, for distinguishing Versicolour from Virginica irises, (as opposed to distinguishing Versicolour from Setosa irises).
#
# These questions are specific examples of a general question. Definite a set of positive classes $P\in C$ and a set of negative classes $N\in C$. For a single observation $x$, we can ask why our model predicts it belongs to a positive class rather than a negative class; $f(x)\subset P \& f(x)\not\subset N$? For a sample $X$, we can ask which features best distinguish positive classes from negative classes.

# %%
import warnings
warnings.simplefilter('ignore')

import gshap
from gshap.classification import ClassificationDistance

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
# Load iris dataset and train support vector classifier
iris = load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y)
clf = SVC(probability=True)
clf.fit(X_train, y_train)
print('Test score: % .4f' % clf.score(X_test, y_test))
# Out:
# Test score:  0.9737

# %%
# Measure classification distance between classes 1 and 0
g_10 = ClassificationDistance(
    positive_classes=[1], negative_classes=[0]
)
# Select observations classified as 1 or 0
X_train_10, X_test_10 = g_10.select_observations(
    clf.predict, X_train, X_test
)
# Explain why observations are classified as 1 and not 0
explainer_10 = gshap.KernelExplainer(
    clf.predict_proba, X_train_10, g_10
)

# Measure classification distance between classes 1 and 2
g_12 = ClassificationDistance([1], [2])
# Select observations classified as 1 or 2
X_train_12, X_test_12 = g_12.select_observations(
    clf.predict, X_train, X_test
)
# Explain why observations are classified as 1 and not 2
explainer_12 = gshap.KernelExplainer(
    clf.predict_proba, X_train_12, g_12
)

# %%
# Select observations classified as 1
X_test_1 = X_test[clf.predict(X_test) == 1]
# Compute average g value for observations classified as 1 or 0
gval_10 = g_10(clf.predict_proba(X_train_10))
# Compute average g value for observations classified as 1 or 2
gval_12 = g_12(clf.predict_proba(X_train_12))

# %%
"""Compute G-SHAP values

Parameters
----------
output : np.array
    (# classes x # samples) vector output by the model.
g : callable
    g_10 or g_12; measures classification distance.
gval : scalar
    gval_10 or gval_12; average g value for background data.
explainer : KernelExplainer
    explainer_10 or explainer_12
"""
def compute_gshap(output, g, gval, explainer):
    delta = g(output) - gval
    gshap_values = explainer.gshap_values(obs, nsamples=1000)    
    print('Percentage points more likely to be classified as 1 than the average observation: % .2f' % (100*delta))
    print('Feature importances sum to total: % .2f' % (100*gshap_values.sum()))
    return gshap_values

# Select example observation(s) from test data
obs = X_test_1[1]

# Create scatter plot of petal length and width
# these are the most important features
plt.scatter(X[:,2], X[:,3], c=y)
plt.scatter(obs[2], obs[3], c='red')
plt.xlabel(iris['feature_names'][2])
plt.ylabel(iris['feature_names'][3])
plt.show()

# Compute model output for example observation
output = clf.predict_proba(obs.reshape((1,-1)))
# Compute G-SHAP values
gshap_values_10 = compute_gshap(output, g_10, gval_10, explainer_10)
gshap_values_12 = compute_gshap(output, g_12, gval_12, explainer_12)

# Plot results
df = pd.DataFrame({
    'Features': iris['feature_names']*2,
    'G-SHAP': list(gshap_values_10) + list(gshap_values_12), 
    'Comparison': [iris['target_names'][0]]*4 + [iris['target_names'][2]]*4
})
sns.catplot(
    x='G-SHAP', y='Features', hue='Comparison', data=df, kind='bar',
    orient='h'
)
# Out:
# Percentage points more likely to be classified as 1 than the average observation:  50.59
# Feature importances sum to total:  48.83
# Percentage points more likely to be classified as 1 than the average observation:  46.14
# Feature importances sum to total:  46.53
